# %%
import os
import numpy as np

f0 = pd.read_csv(os.getcwd()+'/T927K1/[MM927hflip1]Graph_Reports[F0].txt',header=None)
f1 = pd.read_csv(os.getcwd()+'/T927K1/[MM927hflip1]Graph_Reports[F1].txt',header=None)
f2 = pd.read_csv(os.getcwd()+'/T927K1/[MM927hflip1]Graph_Reports[F2].txt',header=None)
f3 = pd.read_csv(os.getcwd()+'/T927K1/[MM927hflip1]Graph_Reports[F3].txt',header=None)
f4 = pd.read_csv(os.getcwd()+'/T927K1/[MM927hflip1]Graph_Reports[F4].txt',header=None)

# %%
fsum = f0 + f1 + f2 + f3 + f4

# %%
fsum2 = fsum/5

# %%
fsum2
# Out:
#              0         1          2         3
# 0    54.484126  0.979601  36.105474  2.504588
# 1    61.706348  0.854655  51.240981  1.713050
# 2    64.682539  0.800838  49.581530  1.143207
# 3    65.694444  0.763070  52.532693  1.017827
# 4    69.722223  0.702617  53.348666  1.003637
# 5    72.539682  0.639450  50.916531  1.391074
# 6    75.277777  0.574206  44.096321  2.076269
# 7    79.067459  0.504171  65.104391  1.408475
# 8    82.063493  0.444617  59.965053  2.251721
# 9    84.146826  0.403791  47.402823  1.682908
# 10   86.369048  0.352839  64.374548  0.869273
# 11   88.690475  0.302000  68.930826  0.884334
# 12   89.285715  0.275218  66.577156  1.289075
# 13   90.853174  0.250077  68.749999  1.153845
# 14   91.230158  0.244924  62.587031  1.653187
# 15   91.150794  0.241049  68.665899  1.134015
# 16   91.527777  0.231869  65.363457  1.270044
# 17   92.261905  0.209144  66.224522  1.412917
# 18   93.670636  0.183712  70.129870  1.033594
# ...

# %%
np.where(fsum2[2]>=76.2)
# Out:
# (array([169]),)

# %%
f0[2][169]
# Out:
# 71.21212

# %%
fsum2[2][168]
# Out:
# 75.32648019999999
